# %%
# Import Libraries ที่ต้องใช้
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, GlobalAveragePooling1D

# เชื่อมต่อ Google Drive
from google.colab import drive
drive.mount('/content/drive')

# --- โหลดข้อมูล ---
data_path = '/content/drive/MyDrive/Colab Notebooks/Thai_Quant_AI_Project/02_data/set50_processed_data.csv'
df = pd.read_csv(data_path, index_col='Date', parse_dates=True)

print("โหลดข้อมูลสำเร็จ!")
# Out:
# Mounted at /content/drive
# โหลดข้อมูลสำเร็จ!

# %%
# --- 1. ปรับสเกลข้อมูล ---
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# --- 2. แบ่งข้อมูล Train/Test ---
training_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[0:training_size, :]
test_data = scaled_data[training_size - 60: , :]

# --- 3. สร้างชุดข้อมูลแบบหน้าต่าง (Windowing) ---
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), :]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 3])
    return np.array(dataX), np.array(dataY)

time_step = 60
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

print("เตรียมข้อมูลสำเร็จ!")
print("Shape ของ X_train:", X_train.shape)
print("Shape ของ y_train:", y_train.shape)
# Out:
# เตรียมข้อมูลสำเร็จ!
# Shape ของ X_train: (1852, 60, 16)
# Shape ของ y_train: (1852,)

# %%
# --- สร้างฟังก์ชันสำหรับ Transformer Block ---
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # --- Attention Block ---
    # Multi-Head Attention: มองข้อมูลจากหลายๆ มุม
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = Dropout(dropout)(x)
    x = LayerNormalization(epsilon=1e-6)(x + inputs) # Skip Connection

    # --- Feed Forward Block ---
    # ส่วนประมวลผลหลังจาก Attention
    ffn = tf.keras.Sequential([
        Dense(ff_dim, activation="relu"),
        Dense(inputs.shape[-1])
    ])
    x = ffn(x)
    x = Dropout(dropout)(x)
    x = LayerNormalization(epsilon=1e-6)(x + x) # Skip Connection
    return x

# --- สร้างฟังก์ชันสำหรับประกอบโมเดลทั้งหมด ---
def build_transformer_model(
    input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=0, mlp_dropout=0
):
    inputs = Input(shape=input_shape)
    x = inputs

    # --- Positional Encoding ---
    # Transformer ไม่รู้ลำดับข้อมูล เราต้องเพิ่มข้อมูลตำแหน่งเข้าไป
    positions = tf.range(start=0, limit=input_shape[0], delta=1)
    pos_embedding = tf.keras.layers.Embedding(input_dim=input_shape[0], output_dim=input_shape[1])(positions)
    x = x + pos_embedding

    # --- Stacking Transformer Blocks ---
    # สร้าง Transformer Block ซ้อนกันหลายๆ ชั้นเพื่อให้เรียนรู้ได้ลึกขึ้น
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # --- Output Block ---
    # รวมผลลัพธ์จากทุก Timestep ให้เป็นหนึ่งเดียว
    x = GlobalAveragePooling1D(data_format="channels_first")(x)

    # MLP (Multi-Layer Perceptron) เพื่อทำนายผลสุดท้าย
    for dim in mlp_units:
        x = Dense(dim, activation="relu")(x)
        x = Dropout(mlp_dropout)(x)

    outputs = Dense(1)(x) # Output สุดท้ายคือราคาที่ทำนาย
    return Model(inputs, outputs)

# --- กำหนดค่า Hyperparameters และสร้างโมเดล ---
input_shape = X_train.shape[1:]

model = build_transformer_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

# Compile โมเดล
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 60, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 60, 16)    │          0 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 60, 16)    │     68,624 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 60, 16)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 60, 16)    │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 60, 16)    │         32 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 60, 16)    │        148 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 60, 16)    │          0 │ sequential[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 60, 16)    │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 60, 16)    │     68,624 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 60, 16)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 60, 16)    │          0 │ dropout_4[0][0],  │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_1        │ (None, 60, 16)    │        148 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 60, 16)    │          0 │ sequential_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 60, 16)    │          0 │ dropout_5[0][0],  │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 60, 16)    │     68,624 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 60, 16)    │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 60, 16)    │          0 │ dropout_7[0][0],  │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 60, 16)    │        148 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 60, 16)    │          0 │ sequential_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 60, 16)    │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 60, 16)    │     68,624 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 60, 16)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 60, 16)    │          0 │ dropout_10[0][0], │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_3        │ (None, 60, 16)    │        148 │ layer_normalizat… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 60, 16)    │          0 │ sequential_3[0][… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 60, 16)    │          0 │ dropout_11[0][0], │
# │                     │                   │            │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 60, 16)    │         32 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 60)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 128)       │      7,808 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 128)       │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │        129 │ dropout_12[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 283,281 (1.08 MB)
#  Trainable params: 283,281 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# เริ่มการฝึกสอนโมเดล
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=64,
    verbose=1
)

# --- บันทึกโมเดลที่เทรนเสร็จแล้ว ---
model_path = '/content/drive/MyDrive/Colab Notebooks/Thai_Quant_AI_Project/03_models/transformer_upgrade_model.h5'
model.save(model_path)
print(f"โมเดลถูกบันทึกเรียบร้อยที่: {model_path}")
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - loss: 0.3612 - val_loss: 0.2215
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - loss: 0.0466 - val_loss: 0.1155
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0327 - val_loss: 0.1079
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 0.0348 - val_loss: 0.1102
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - loss: 0.0346 - val_loss: 0.1024
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0333 - val_loss: 0.1027
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0341 - val_loss: 0.1074
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0341 - val_loss: 0.1197
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - loss: 0.0348 - val_loss: 0.1144
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0330 - val_loss: 0.1094
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0313 - val_loss: 0.1174
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0321 - val_loss: 0.1101
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0324 - val_loss: 0.1059
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0327 - val_loss: 0.1035
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0328 - val_loss: 0.1165
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - loss: 0.0303 - val_loss: 0.1101
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0329 - val_loss: 0.1080
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 0.0318 - val_loss: 0.1207
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0350 - val_loss: 0.1104
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0344 - val_loss: 0.1164
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - loss: 0.0327 - val_loss: 0.1172
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0323 - val_loss: 0.0980
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0326 - val_loss: 0.1109
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0329 - val_loss: 0.0936
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - loss: 0.0325 - val_loss: 0.1094
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0327 - val_loss: 0.0945
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0307 - val_loss: 0.0898
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - loss: 0.0317 - val_loss: 0.1192
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0286 - val_loss: 0.1053
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0341 - val_loss: 0.0927
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0344 - val_loss: 0.0936
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0340 - val_loss: 0.1098
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0336 - val_loss: 0.0965
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0310 - val_loss: 0.0968
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0331 - val_loss: 0.0885
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0335 - val_loss: 0.1181
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0312 - val_loss: 0.1020
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0315 - val_loss: 0.1154
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0317 - val_loss: 0.0981
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0312 - val_loss: 0.0972
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0344 - val_loss: 0.1139
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0321 - val_loss: 0.0900
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0329 - val_loss: 0.1043
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0309 - val_loss: 0.0929
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0307 - val_loss: 0.1205
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0333 - val_loss: 0.1205
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0322 - val_loss: 0.1088
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - loss: 0.0325 - val_loss: 0.1153
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0338 - val_loss: 0.1105
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0304 - val_loss: 0.0993
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# โมเดลถูกบันทึกเรียบร้อยที่: /content/drive/MyDrive/Colab Notebooks/Thai_Quant_AI_Project/03_models/transformer_upgrade_model.h5
